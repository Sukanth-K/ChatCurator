# %%
! pip install replicate

import os
from googleapiclient.discovery import build
from google.colab import files
import replicate
import re
import time

os.environ["REPLICATE_API_TOKEN"] = "r8_" # get a replicate token for llama model 7B
api_key = ''# get a YouTube public API token
# Out:
# Requirement already satisfied: replicate in /usr/local/lib/python3.10/dist-packages (0.24.0)
# Requirement already satisfied: httpx<1,>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from replicate) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from replicate) (23.2)
# Requirement already satisfied: pydantic>1 in /usr/local/lib/python3.10/dist-packages (from replicate) (2.6.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from replicate) (4.9.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.21.0->replicate) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.21.0->replicate) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.21.0->replicate) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.21.0->replicate) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.21.0->replicate) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.21.0->replicate) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>1->replicate) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>1->replicate) (2.16.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.21.0->replicate) (1.2.0)

# %%
# Collect YouTube URL from the user
youtube_url = input("Enter the YouTube URL: ")

# Extract video ID from the URL
video_id = youtube_url.split('v=')[-1]

# https://www.youtube.com/watch?v=hW0-bPsS67I
# Out:
# Enter the YouTube URL: https://www.youtube.com/watch?v=hW0-bPsS67I

# %% [markdown]
# ## Generate

# %%
import time

while True:
    # Set up YouTube Data API
    youtube = build('youtube', 'v3', developerKey=api_key)

    # Function to fetch messages from YouTube live chat and video title
    def fetch_live_chat_messages_and_title(video_id):
        try:
            # Fetch live streaming details for the specified video ID
            video_response = youtube.videos().list(part='snippet,liveStreamingDetails', id=video_id).execute()

            # Extract video title
            video_title = video_response['items'][0]['snippet']['title']

            # Fetch live chat messages using the video ID
            live_chat_response = youtube.liveChatMessages().list(
                liveChatId=video_response['items'][0]['liveStreamingDetails']['activeLiveChatId'],
                part='snippet',
                maxResults=10
            ).execute()

            # Extract live chat messages
            messages = live_chat_response.get('items', [])

            return video_title, messages
        except Exception as e:
            print(f"An error occurred: {str(e)}")
            return None, []

    # Example usage:
    video_title, messages = fetch_live_chat_messages_and_title(video_id)

    # Save the video title and the last 10 messages to a file
    file_path = 'last_10_messages_with_title.txt'
    with open(file_path, 'w') as file:
        file.write(f"Video Title: {video_title}\n\n")
        for message in messages:
            if 'snippet' in message and 'textMessageDetails' in message['snippet']:
                file.write(message['snippet']['textMessageDetails']['messageText'] + '\n')

    try:
        # Open the file and read its contents
        with open(file_path, 'r') as file:
            # Read the contents of the file
            file_contents = file.read()

            # Variable to store the extracted text
            extracted_text = ""

            for event in replicate.stream(
                    "meta/llama-2-7b-chat",
                    input={
                        "debug": False,
                        "top_k": -1,
                        "top_p": 1,
                        "prompt": file_contents,
                        "temperature": 0.75,
                        "system_prompt": "Pick 1 comment most relevant to the title of the video, output format: **{comment}**",
                        "max_new_tokens": 800,
                        "min_new_tokens": -1,
                        "repetition_penalty": 1
                    },
            ):
                # Concatenate the text from each event
                extracted_text += str(event)

        # Sample text containing sentences enclosed within "**"
        text = extracted_text

        # Regular expression pattern to match sentences enclosed within "**"
        pattern = r'\*\*(.*?)\*\*'

        # Extract sentences enclosed within "**"
        extracted_sentences = re.findall(pattern, text, re.DOTALL)

        # Print the extracted sentences
        for sentence in extracted_sentences:
            print(sentence.strip())

    except FileNotFoundError:
        print(f"The file '{file_path}' does not exist.")

    # Sleep for 10 seconds
    time.sleep(10)
# Out:
# "You don't understand about your second amendment up there in the north, but it's a little different around here in the south"
# "It is no different"
# People have the right to be armed
# "Why is he wearing black gloves inside at a rally?"
# "People have the right to be armed"
# @No One:
# "Giving up our weapons lol"
# @No One: Lol Crazy Democrats!
# The second amendment is for standing up to tyrannical government
# joe is cooked
# Susan:
# @steven mazur - Yeah, that's why there are more school shootings here than any other country.
# "STAGED BOMBS"
# Rick:
# "UNSTOPPABLE,"
# "There is no other side"
# What cracks me up is hypocrite Hollywood always for gun control and anti-guns, and then 80% of their movies are full of people shooting guns, lmao 🤣🤦🏻‍♂️.
# What cracks me up is hypocrite Hollywood always for gun control and anti-guns and then 80% of their movies are full of people shooting guns, lmao 🤣🤦🏻‍♂️.
# What cracks me up is hypocrite Hollywood always for gun control and anti-guns and then 80% of their movies are full of people shooting guns, lmao 🤣🤦🏻‍♂️.
# Wannabe dictator Biden
# No one cares about your gun laws, Susan. Illegals murder all the time here and you're worried about us with guns? 🤣😂
# Illegals murder all the time here and Susan is worried about us with guns 🤣😂
# @steven mazur: Countries with strict gun laws have nowhere near our gun crime rate - and no school massacres.
# Guns are the PROBLEM, stupid, not the SOLUTION!
# "Guns are the PROBLEM, stupid, not the SOLUTION!"
# Guns are the PROBLEM, stupid, not the SOLUTION!
# ok, it must be time for his diaper change, but no, he won't leave as long as there are still a few there lookin' at him.
# You being so hung up on your guns is childish as hell -- like being afraid of the boogey man. Seriously. It gets very old.
# "You being so hung up on your guns is childish as hell -- like being afraid of the boogey man. Seriously. It gets very old."
# "Biden is old. Trump is nearly as old and much more demented."
# "Sleepy joe"
# "Trump is in terrible shape - all that cocaine in the '80s took its toll."
# "Fear"
# Fear
# "Trump can't be the worst President ever, can he? Biden's corrupt"
# Trump can't be the worst President ever, can he?
# "Trump can't be the worst President ever, can he? Biden's corrupt"
# @Tornado: Biden's corrupt
# @Tornado Yeah they've learned well from their cult leader, Joe Lie-den, lol.
# The comment most relevant to the title of the video is:
# DEMOCRATS = GOODFELLAS + GHETTO DWELLERS + WEEKEND AT BERNIES! 😆 🤣 😂 😹
# @No One:
# @No One excuse me
# @No One did you relapse again
# Where's Mercedes? lol
# DEMOCRATS = GOODFELLAS + GHETTO DWELLERS + WEEKEND AT BERNIES! 😆 🤣 😂 😹 😆 🤣
# "I honestly just wanna lay my head down. I have to worry about a nuclear war. Is that so hard to ask Dems?"
# I honestly just wanna lay my head down. I have to worry about a nuclear war. Is that so hard to ask Dems?
# "if only I had friends"
# @No One did you relapse again
# Danny: don’t forget the dancing ballerina 🩰 🤣😂😂
# Tip toe through the tulips 💐 at the White House 🤣😂😂
# Danny: tip toe through the tulips 💐 at the White House 🤣😂😂
# Danny: tip toe through the tulips 💐 at the White House 🤣😂😂
# Join MAGA might get 1 or 2
# "Easily proven with typical Chi Square testing."
# "Easily proven with typical Chi Square testing."
# traumatic childhood 😢
# traumatic childhood 😢
# No one wants to be friends with the Democrat nowadays, bro
# Tip toe through the tulips 💐 at the White House 🤣😂😂
# Yes 🙌 Danny 🤣😂😂😂
# Yes 🙌 Danny 🤣😂😂😂
# Yes 🙌 Danny 🤣😂😂😂
# @Tornado, 🤣🤣🤣🤣 if only there was a way we could just go back to bows and arrows
# if only there was a way we could just go back to bows and arrows
# "Have you looked at the blue city of Chicago for example? Just to Hilariously bad 🤣😂😂🤣"
# "Have you looked at the blue city of Chicago for example? Just to Hilariously bad 🤣😂😂🤣"
# How about Kansas City?
# The increase in crime in NYC is due to the influx of migrants, not Trump's dog.
# IMPORT 3RD WORLD BECOME 3RD WORLD!!!
# IMPORT 3RD WORLD BECOME 3RD WORLD!!!
# @Mr Stringpicker,Is that whats wrong with his crazy dog,it's on Cocaine, lmao?
# @Danny Yes we solved it😅🤣😂 call up the humane society
# @No One: who are you talking to dude
# @No One who are you talking to dude:
# @Danny Yes we solved it😅🤣😂 call up the humane society
# @Danny Yes we solved it😅🤣😂 call up the humane society
# @Tornado, lol
# @Tornado ,lol
# not even Joe's dog likes him
# "lefties were better off with Trump"
# Windston: 🤣😂😂 lefties were better off with Trump
# @Danny True 🤣😂: if Don had a dog he'd kick it,
# @No One ok wise guy, you wanna talk crime with me? ok, lets go. let me test your basic knowledge of crime, which race in this country commit the most crimes? don't google it
# If Don had a dog he'd kick it
# @No One:
# "Don't worry, there's Spider-Man in NYC"
# Crazy Commander,lol.🏃🏼‍♂️🐕‍🦺
# susan alexander
# susan alexander
# "Narcissists never have pets"
# "Biden did something to that dog"
# WNDSTON:
# SUSAN: What makes you so hateful? I never seen Trump hurt any animals 🙄🙄
# @Windston Miller. Maybe you should donate to trump's legal fund lol
# "Maybe you should donate to trump's legal fund lol"
# @Windston Miller. excuse me, you better ask somebody. check yourself before you wreck yourself, google my IQ
# @Tornado,Is that what Susan said, lmao? I had to block her,lol.🚮🚫
# @Tornado,Is that what Susan said, lmao? I had to block her,lol.🚮🚫
# "Dork Rinds"
# GOD BLESS TRUMP, AM OUT.:washhands:
# loser and traitor
# dems in panic mode
# "Lies lies lies"
# Somebody who has the highest IQ in the world ???
# No wars under Trump
# haven't you ever listened to Joe Biden?
# Another Brian BLOCKED 🚫🚮
# Look, it’s Uncle Ramble Standers !! Lies about Unions !
# "Jail trump! Save America"
# @Pork Rinds I asked somebody and I didn't get an answer
# @Toker I know that is a lie dude
# @Barnabus
# It’s Uncle Ramble Standers !
# He’s been found guilty with proven criminal charges and people still will vote for this criminal. Wow
# jail Eduardo save america
# LEGAL ALL THE WAY, NO LOOKING OUT FOR ICE.
# @Toker who did you ask? Tornado K1d? she is always drunken
# @Barnabus:
# @Toker who did you ask? Tornado K1d? she is always drunken
# I’m already here in jail, waiting for trump to join me😂😂😂
# "Trump was at no time ever accused of charged with or convicted of rape so there is that🤔"
# @Pork Rinds I googled ME:
# "Trump went to court, still walking around 😆"
# "Watch trump be free we’ll get 4 years of democrats bitching and moaning"
# @Toker are you drunk dude
# @Pork Rinds why would you say that?
# @Pork Rinds: Why would you say that?
# "libs tears this year :elbowcough:"
# Brother, jumping borders, you don’t expect me to jump in your phone
# I have aliens in my pants
# "Sure, Trump wants crime, Putin supporter, sounds nuts"
# "There's aliens everywhere"
# "boo hoo, im blocking you😭😭"
# @United,Gay clown crybaby 🤡🤡🤡
# "Trump murdered Ashley Babbit"
# "I just told him about five of them on my Home drop them off at immigration"
# don't allow illegals to work in the US they will leave
# Joe is a pushover that’s why
# I think immigrants work harder than locals, locals seem to be fat
# The most relevant comment to the title of the video is:
# "I think immigrants work harder than locals, locals seem to be fat."
# I think immigrants work harder than locals, locals seem to be fat
# "I think immigrants work harder than locals, locals seem to be fat"
# Biden's a proven liar time and time again but they don't seem to care about that for some reason. 🤔
# Biden's a proven liar time and time again but they don't seem to care about that for some reason. 🤔
# Will DT support NATO if push comes to shove?
# "Go ahead, vote for this criminal, let’s see how much more crap he brings in."
# "Go ahead, vote for this criminal, let’s see how much more crap he brings in."
# "you're pushing it Merkin😠" - E. Wheeler
# "you're pushing it Merkin😠" - E. Wheeler
# "The current democratic party has been captured by something, and Trump is not the guy to fix it... ...RFK Jr is."
# The current democratic party has been captured by something, and Trump is not the guy to fix it... ...RFK Jr is.
# "The current democratic party has been captured by something, and Trump is not the guy to fix it... ...RFK Jr is."
# "Civil war hmm 🤔"
# "An absolute cult. Sad!"
# @Barnabus,🤜🏻🤛🏻🇺🇸:
# @Barnabus,🤜🏻🤛🏻🇺🇸
# @Barnabus:
# @Barnabus,🤜🏻🤛🏻🇺🇸:
# @Freexplx Putin also said that Joe Biden is easier to control
